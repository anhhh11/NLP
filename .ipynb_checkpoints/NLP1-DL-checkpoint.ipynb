# %%
import re
import unicodedata
import torch
import torch.nn as nn
import torch
from torch.autograd import Variable
from torch import optim
from collections import Counter
import torch.nn.functional as F
import pickle
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import nltk
torch.manual_seed(10)
# Enable inline plotting
nltk.download('punkt')
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /home/computer/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# if gpu is to be used
use_cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_cuda else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_cuda else torch.ByteTensor
Tensor = FloatTensor
Variable = torch.autograd.Variable

# %%
file = open('./data/Training_shuf.txt', 'r')
data = []
X = [] # text 
y = [] # label (text)
for line in file:
    row = line.split(' ', 1)
    data.append((row[1].strip(), row[0].split('__')[1]))
    X.append(row[1].strip())
    y.append(row[0].split('__')[1])

# %%
le = preprocessing.LabelEncoder()
le.fit(y)
Y_train = le.transform(y)
number_of_class = le.classes_.size

# %%
stop_words = []
with open('./data/vietnamese-stopwords.txt', 'r') as file_stop_words:
    for line in file_stop_words:
        stop_words.append(line.strip())

# %%
np.save('./data/classes.npy', le.classes_)

# %%
class Vocabulary(object):
    """Simple vocabulary wrapper."""
    def __init__(self, stop_words, counter):
        self.stop_words = stop_words
        self.word2idx = {}
        self.idx2word = {}
        self.stop_words = {}
        self.counter = counter
        self.idx = 0

    def add_word(self, word):
        if not word in self.word2idx and word not in self.stop_words:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def __call__(self, word):
        if not word in self.word2idx:
            return self.word2idx['<unk>']
        return self.word2idx[word]

    def __len__(self):
        return len(self.word2idx)
    
    def get_text_indexes(self, text):
         return [(self(token),self.counter[token]) for token in nltk.tokenize.word_tokenize(text.lower()) if token not in self.stop_words]
    
    def get_text_string(self, indexes):
        return [self.idx2word[index] for index in indexes]
    

def build_vocab(texts, stop_words, threshold = 2):
    counter = Counter()
    for i, text in enumerate(texts):
        tokens = [t for t in nltk.tokenize.word_tokenize(text.lower()) if t not in stop_words and len(t) > 2]
        counter.update(tokens)
        if i % 1000 == 0:
            print("[%d/%d] Tokenized the texts." %(i, len(texts)))
    
    words = [word for word, cnt in counter.items() if cnt >= threshold]
    
    vocab = Vocabulary(stop_words, counter)
    vocab.add_word('<pad>')
    vocab.add_word('<start>')
    vocab.add_word('<end>')
    vocab.add_word('<unk>')

    for i, word in enumerate(words):
        vocab.add_word(word)
    return vocab
    
class Model(torch.nn.Module) :
    def __init__(self,embedding_dim,hidden_dim,vocab_limit,number_of_class) :
        super(Model,self).__init__()
        self.hidden_dim = hidden_dim
        self.embeddings = nn.Embedding(vocab_limit, embedding_dim)
        self.lstm1 = nn.LSTM(embedding_dim + 1,hidden_dim,dropout=0.5)
        self.linear1 = nn.Linear(hidden_dim,number_of_class)
    def forward(self,inputs,bow,hidden) :
        x = self.embeddings(inputs).view(len(inputs),1,-1)
        x = torch.cat([x,bow.view(x.size(0),x.size(1),1)], dim=2)
        lstm_out1,lstm_h1 = self.lstm1(x,hidden)
        x = lstm_out1[-1]
        x = self.linear1(x)
        x = F.log_softmax(x)
        return x,lstm_h1
    def init_hidden(self) :
        return (Variable(torch.zeros(1, 1, self.hidden_dim).type(FloatTensor)),Variable(torch.zeros(1, 1, self.hidden_dim).type(FloatTensor)))

# %%
# %%time
use_preload_vocabs = True
if use_preload_vocabs:
    with open('./data/vocabs.pkl','rb') as f:
        vocabs = pickle.load(f)
else:
    vocabs = build_vocab(X, stop_words)
    with open('./data/vocabs.pkl','wb') as f:
        pickle.dump(vocabs, f)
vocab_limit = len(vocabs)
# Out:
# CPU times: user 28.4 ms, sys: 0 ns, total: 28.4 ms
# Wall time: 25.9 ms

# %%
vocabs.stop_words = stop_words

# %%
model = Model(80,100,vocab_limit,number_of_class)
if(use_cuda):
    model.cuda()

loss_function = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
# %%time
epochs = 20

torch.save(model.state_dict(), './data/model' + str(0)+'.pth')
print('starting training')
X_sample = X#[2000:4000]
Y_train_sample = Y_train#[2000:4000]
total_freq_words = sum(vocabs.counter.values())
for i in range(epochs):
    avg_loss = 0.0
    for idx, (x, y_train) in enumerate(zip(X_sample, Y_train_sample)):
        if not idx == 0:
            input_data, input_data_bow = zip(*vocabs.get_text_indexes(x))
            input_data = Variable(LongTensor(input_data))
            input_data_bow = FloatTensor(input_data_bow) / total_freq_words 
            # F.normalize(FloatTensor(input_data_bow),dim=0)
            # print(input_data_bow)
            input_data_bow = Variable(input_data_bow)
            # print(input_data_bow.shape, input_data.shape)
            
            y_train = y_train.item()
            target_data = Variable(LongTensor([y_train]))
            hidden = model.init_hidden()
            model.zero_grad()
            y_pred,_ = model(input_data,input_data_bow,hidden)
            loss = loss_function(y_pred,target_data)
            avg_loss += loss.data[0]
            
            if idx%500 == 0 or idx == 1:
                print('epoch :%d iterations :%d loss :%g'%(i,idx,loss.data[0]))
                
            loss.backward()
            optimizer.step()
    torch.save(model.state_dict(), './data/' + str(i+1)+'.pth')            
    print('the average loss after completion of %d epochs is %g'%((i+1),(avg_loss/len(X_sample))))
# Out:
# starting training
# epoch :0 iterations :1 loss :2.35323
# /home/computer/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:65: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# epoch :0 iterations :500 loss :2.57905
# epoch :0 iterations :1000 loss :2.14521
# epoch :0 iterations :1500 loss :2.12214
# epoch :0 iterations :2000 loss :2.10907
# epoch :0 iterations :2500 loss :2.13964
# epoch :0 iterations :3000 loss :2.19514
# epoch :0 iterations :3500 loss :2.78045
# epoch :0 iterations :4000 loss :1.47368
# epoch :0 iterations :4500 loss :2.68557
# epoch :0 iterations :5000 loss :2.22539
# epoch :0 iterations :5500 loss :2.84578
# epoch :0 iterations :6000 loss :1.10089
# epoch :0 iterations :6500 loss :1.74738
# epoch :0 iterations :7000 loss :0.925474
# epoch :0 iterations :7500 loss :0.340396
# epoch :0 iterations :8000 loss :0.489485
# epoch :0 iterations :8500 loss :1.79475
# epoch :0 iterations :9000 loss :0.18229
# epoch :0 iterations :9500 loss :1.98812
# the average loss after completion of 1 epochs is 1.70931
# epoch :1 iterations :1 loss :1.07808
# epoch :1 iterations :500 loss :1.30159
# epoch :1 iterations :1000 loss :0.611976
# epoch :1 iterations :1500 loss :2.44001
# epoch :1 iterations :2000 loss :0.103445
# epoch :1 iterations :2500 loss :0.437539
# epoch :1 iterations :3000 loss :0.229476
# epoch :1 iterations :3500 loss :0.460958
# epoch :1 iterations :4000 loss :0.406368
# epoch :1 iterations :4500 loss :0.618027
# epoch :1 iterations :5000 loss :1.51331
# epoch :1 iterations :5500 loss :2.86995
# epoch :1 iterations :6000 loss :0.0843539
# epoch :1 iterations :6500 loss :0.151715
# epoch :1 iterations :7000 loss :0.254049
# epoch :1 iterations :7500 loss :0.050221
# epoch :1 iterations :8000 loss :0.0477982
# epoch :1 iterations :8500 loss :0.767518
# epoch :1 iterations :9000 loss :0.051825
# epoch :1 iterations :9500 loss :0.174359
# the average loss after completion of 2 epochs is 0.866567
# epoch :2 iterations :1 loss :0.186314
# epoch :2 iterations :500 loss :2.40153
# epoch :2 iterations :1000 loss :0.00824928
# epoch :2 iterations :1500 loss :1.51093
# epoch :2 iterations :2000 loss :0.0190911
# epoch :2 iterations :2500 loss :0.138329
# epoch :2 iterations :3000 loss :0.0120101
# epoch :2 iterations :3500 loss :0.0153069
# epoch :2 iterations :4000 loss :0.0132775
# epoch :2 iterations :4500 loss :0.256234
# epoch :2 iterations :5000 loss :0.068522
# epoch :2 iterations :5500 loss :2.13575
# epoch :2 iterations :6000 loss :0.00707436
# epoch :2 iterations :6500 loss :0.0454655
# epoch :2 iterations :7000 loss :0.120366
# epoch :2 iterations :7500 loss :0.106678
# epoch :2 iterations :8000 loss :0.0169554
# epoch :2 iterations :8500 loss :0.95902
# epoch :2 iterations :9000 loss :0.0386467
# epoch :2 iterations :9500 loss :0.0260453
# the average loss after completion of 3 epochs is 0.527147
# epoch :3 iterations :1 loss :0.0141373
# epoch :3 iterations :500 loss :0.0379186
# epoch :3 iterations :1000 loss :0.00357533
# epoch :3 iterations :1500 loss :0.0423326
# epoch :3 iterations :2000 loss :0.00515175
# epoch :3 iterations :2500 loss :0.0524759
# epoch :3 iterations :3000 loss :0.00392485
# epoch :3 iterations :3500 loss :0.00912094
# epoch :3 iterations :4000 loss :0.00931454
# epoch :3 iterations :4500 loss :0.107518
# epoch :3 iterations :5000 loss :0.0528045
# epoch :3 iterations :5500 loss :0.245609
# epoch :3 iterations :6000 loss :0.00784969
# epoch :3 iterations :6500 loss :0.0215368
# epoch :3 iterations :7000 loss :0.0411024
# epoch :3 iterations :7500 loss :0.016181
# epoch :3 iterations :8000 loss :0.0142274
# epoch :3 iterations :8500 loss :0.336674
# epoch :3 iterations :9000 loss :0.309312
# epoch :3 iterations :9500 loss :0.0104475
# the average loss after completion of 4 epochs is 0.352502
# epoch :4 iterations :1 loss :0.0126567
# epoch :4 iterations :500 loss :0.0324864
# epoch :4 iterations :1000 loss :0.00144386
# epoch :4 iterations :1500 loss :0.0240479
# epoch :4 iterations :2000 loss :0.00394726
# epoch :4 iterations :2500 loss :0.0151401
# epoch :4 iterations :3000 loss :0.0248857
# epoch :4 iterations :3500 loss :0.00282383
# epoch :4 iterations :4000 loss :0.00157547
# epoch :4 iterations :4500 loss :0.505444
# epoch :4 iterations :5000 loss :0.0132942
# epoch :4 iterations :5500 loss :0.41106
# epoch :4 iterations :6000 loss :0.00208378
# epoch :4 iterations :6500 loss :0.00766087
# epoch :4 iterations :7000 loss :0.0132575
# epoch :4 iterations :7500 loss :0.00129414
# epoch :4 iterations :8000 loss :0.00248528
# epoch :4 iterations :8500 loss :0.0855479
# epoch :4 iterations :9000 loss :0.0438843
# epoch :4 iterations :9500 loss :0.00853777
# the average loss after completion of 5 epochs is 0.242679
# epoch :5 iterations :1 loss :0.0146823
# epoch :5 iterations :500 loss :0.956398
# epoch :5 iterations :1000 loss :0.000247002
# epoch :5 iterations :1500 loss :0.00775671
# epoch :5 iterations :2000 loss :0.00152874
# epoch :5 iterations :2500 loss :0.00267029
# epoch :5 iterations :3000 loss :0.000344276
# epoch :5 iterations :3500 loss :0.000317574
# epoch :5 iterations :4000 loss :0.00409603
# epoch :5 iterations :4500 loss :0.00349283
# epoch :5 iterations :5000 loss :0.0128822
# epoch :5 iterations :5500 loss :0.963062
# epoch :5 iterations :6000 loss :0.000566483
# epoch :5 iterations :6500 loss :0.00752163
# epoch :5 iterations :7000 loss :0.00349522
# epoch :5 iterations :7500 loss :0.00104141
# epoch :5 iterations :8000 loss :0.000700951
# epoch :5 iterations :8500 loss :0.100151
# epoch :5 iterations :9000 loss :0.0353837
# epoch :5 iterations :9500 loss :0.0106926
# the average loss after completion of 6 epochs is 0.15334
# epoch :6 iterations :1 loss :0.00522423
# epoch :6 iterations :500 loss :0.0195384
# epoch :6 iterations :1000 loss :0.000185013
# epoch :6 iterations :1500 loss :0.0197101
# epoch :6 iterations :2000 loss :0.000425339
# epoch :6 iterations :2500 loss :0.000551224
# epoch :6 iterations :3000 loss :0.00500059
# epoch :6 iterations :3500 loss :0.000528336
# epoch :6 iterations :4000 loss :0.00423956
# epoch :6 iterations :4500 loss :0.00063324
# epoch :6 iterations :5000 loss :0.00200748
# epoch :6 iterations :5500 loss :0.0190988
# epoch :6 iterations :6000 loss :0.000253677
# epoch :6 iterations :6500 loss :0.00187016
# epoch :6 iterations :7000 loss :0.000365257
# epoch :6 iterations :7500 loss :0.00178719
# epoch :6 iterations :8000 loss :0.000317574
# epoch :6 iterations :8500 loss :0.0801699
# epoch :6 iterations :9000 loss :0.00884819
# epoch :6 iterations :9500 loss :0.00279951
# the average loss after completion of 7 epochs is 0.0916217
# epoch :7 iterations :1 loss :0.00138855
# epoch :7 iterations :500 loss :0.000912666
# epoch :7 iterations :1000 loss :9.53674e-06
# epoch :7 iterations :1500 loss :0.0217829
# epoch :7 iterations :2000 loss :3.14713e-05
# epoch :7 iterations :2500 loss :0.000114441
# epoch :7 iterations :3000 loss :2.19345e-05
# epoch :7 iterations :3500 loss :3.8147e-05
# epoch :7 iterations :4000 loss :0.00149727
# epoch :7 iterations :4500 loss :0.00816441
# epoch :7 iterations :5000 loss :0.000776291
# epoch :7 iterations :5500 loss :0.00172329
# epoch :7 iterations :6000 loss :0.00134945
# epoch :7 iterations :6500 loss :0.000356674
# epoch :7 iterations :7000 loss :0.0037961
# epoch :7 iterations :7500 loss :0.000107765
# epoch :7 iterations :8000 loss :0.000117302
# epoch :7 iterations :8500 loss :0.00144625
# epoch :7 iterations :9000 loss :0.000617981
# epoch :7 iterations :9500 loss :0.000102043
# the average loss after completion of 8 epochs is 0.0659339
# epoch :8 iterations :1 loss :0.00299931
# epoch :8 iterations :500 loss :6.48499e-05
# epoch :8 iterations :1000 loss :2.86102e-06
# epoch :8 iterations :1500 loss :0.00144768
# epoch :8 iterations :2000 loss :2.38419e-05
# epoch :8 iterations :2500 loss :0.000500679
# epoch :8 iterations :3000 loss :0.000115395
# epoch :8 iterations :3500 loss :6.67572e-05
# epoch :8 iterations :4000 loss :0.000161171
# epoch :8 iterations :4500 loss :0.0416036
# epoch :8 iterations :5000 loss :0.00030899
# epoch :8 iterations :5500 loss :0.0318127
# epoch :8 iterations :6000 loss :0.00143814
# epoch :8 iterations :6500 loss :0.000227928
# epoch :8 iterations :7000 loss :0.00342464
# epoch :8 iterations :7500 loss :2.19345e-05
# epoch :8 iterations :8000 loss :9.63211e-05
# epoch :8 iterations :8500 loss :0.105818
# epoch :8 iterations :9000 loss :0.00014019
# epoch :8 iterations :9500 loss :1.90735e-06
# the average loss after completion of 9 epochs is 0.0455274
# epoch :9 iterations :1 loss :0.000128746
# epoch :9 iterations :500 loss :0.000355721
# epoch :9 iterations :1000 loss :9.53674e-07
# epoch :9 iterations :1500 loss :0.00104523
# epoch :9 iterations :2000 loss :9.53674e-06
# epoch :9 iterations :2500 loss :0.000170708
# epoch :9 iterations :3000 loss :4.48227e-05
# epoch :9 iterations :3500 loss :5.72205e-06
# epoch :9 iterations :4000 loss :0.000107765
# epoch :9 iterations :4500 loss :0.0194364
# epoch :9 iterations :5000 loss :0.000354767
# epoch :9 iterations :5500 loss :0.00366163
# epoch :9 iterations :6000 loss :0.000216484
# epoch :9 iterations :6500 loss :7.72476e-05
# epoch :9 iterations :7000 loss :8.39233e-05
# epoch :9 iterations :7500 loss :9.53674e-06
# epoch :9 iterations :8000 loss :0.00265598
# epoch :9 iterations :8500 loss :0.00021553
# epoch :9 iterations :9000 loss :8.2016e-05
# epoch :9 iterations :9500 loss :3.8147e-06
# the average loss after completion of 10 epochs is 0.0350467
# epoch :10 iterations :1 loss :3.8147e-05
# epoch :10 iterations :500 loss :2.03514
# epoch :10 iterations :1000 loss :9.53674e-07
# epoch :10 iterations :1500 loss :0.000243187
# epoch :10 iterations :2000 loss :1.90735e-06
# epoch :10 iterations :2500 loss :0.00033474
# epoch :10 iterations :3000 loss :1.90735e-05
# epoch :10 iterations :3500 loss :9.53674e-06
# epoch :10 iterations :4000 loss :0.000217438
# epoch :10 iterations :4500 loss :0.0390053
# epoch :10 iterations :5000 loss :0.000709534
# epoch :10 iterations :5500 loss :0.00419235
# epoch :10 iterations :6000 loss :0.000832558
# epoch :10 iterations :6500 loss :1.81198e-05
# epoch :10 iterations :7000 loss :0.000164032
# epoch :10 iterations :7500 loss :2.09808e-05
# epoch :10 iterations :8000 loss :0.00527573
# epoch :10 iterations :8500 loss :8.58307e-05
# epoch :10 iterations :9000 loss :0.000271797
# epoch :10 iterations :9500 loss :1.23978e-05
# the average loss after completion of 11 epochs is 0.0304021
# epoch :11 iterations :1 loss :1.23978e-05
# epoch :11 iterations :500 loss :2.76566e-05
# epoch :11 iterations :1000 loss :0
# epoch :11 iterations :1500 loss :3.33786e-05
# epoch :11 iterations :2000 loss :1.90735e-06
# epoch :11 iterations :2500 loss :0.000451088
# epoch :11 iterations :3000 loss :9.53674e-07
# epoch :11 iterations :3500 loss :3.8147e-06
# epoch :11 iterations :4000 loss :0.000157356
# epoch :11 iterations :4500 loss :0.00121784
# epoch :11 iterations :5000 loss :3.43323e-05
# epoch :11 iterations :5500 loss :0.42885
# epoch :11 iterations :6000 loss :7.62939e-06
# epoch :11 iterations :6500 loss :1.14441e-05
# epoch :11 iterations :7000 loss :5.53131e-05
# epoch :11 iterations :7500 loss :4.00543e-05
# epoch :11 iterations :8000 loss :0.00039959
# epoch :11 iterations :8500 loss :6.48499e-05
# epoch :11 iterations :9000 loss :0.000647545
# epoch :11 iterations :9500 loss :0.00132179
# the average loss after completion of 12 epochs is 0.0214275
# epoch :12 iterations :1 loss :9.53674e-07
# epoch :12 iterations :500 loss :4.1008e-05
# epoch :12 iterations :1000 loss :0
# epoch :12 iterations :1500 loss :5.81741e-05
# epoch :12 iterations :2000 loss :2.86102e-06
# epoch :12 iterations :2500 loss :0.0048399
# epoch :12 iterations :3000 loss :0
# epoch :12 iterations :3500 loss :0
# epoch :12 iterations :4000 loss :0.000789642
# epoch :12 iterations :4500 loss :0.00375843
# epoch :12 iterations :5000 loss :0.000181198
# epoch :12 iterations :5500 loss :0.000339508
# epoch :12 iterations :6000 loss :3.43323e-05
# epoch :12 iterations :6500 loss :7.62939e-06
# epoch :12 iterations :7000 loss :2.95639e-05
# epoch :12 iterations :7500 loss :2.38419e-05
# epoch :12 iterations :8000 loss :2.28882e-05
# epoch :12 iterations :8500 loss :1.52588e-05
# epoch :12 iterations :9000 loss :2.47955e-05
# epoch :12 iterations :9500 loss :2.57492e-05
# the average loss after completion of 13 epochs is 0.0204979
# epoch :13 iterations :1 loss :9.53674e-07
# epoch :13 iterations :500 loss :6.77109e-05
# epoch :13 iterations :1000 loss :0
# epoch :13 iterations :1500 loss :1.04904e-05
# epoch :13 iterations :2000 loss :2.19345e-05
# epoch :13 iterations :2500 loss :4.76837e-06
# epoch :13 iterations :3000 loss :0
# epoch :13 iterations :3500 loss :9.53674e-07
# epoch :13 iterations :4000 loss :2.47955e-05
# epoch :13 iterations :4500 loss :0.00291538
# epoch :13 iterations :5000 loss :0.000581741
# epoch :13 iterations :5500 loss :4.76837e-06
# epoch :13 iterations :6000 loss :9.53674e-07
# epoch :13 iterations :6500 loss :8.86917e-05
# epoch :13 iterations :7000 loss :6.67572e-06
# epoch :13 iterations :7500 loss :9.53674e-07
# epoch :13 iterations :8000 loss :6.96182e-05
# epoch :13 iterations :8500 loss :0.00914001
# epoch :13 iterations :9000 loss :2.09808e-05
# epoch :13 iterations :9500 loss :0
# the average loss after completion of 14 epochs is 0.0203995
# epoch :14 iterations :1 loss :0
# epoch :14 iterations :500 loss :0.000540733
# epoch :14 iterations :1000 loss :0
# epoch :14 iterations :1500 loss :7.05719e-05
# epoch :14 iterations :2000 loss :0
# epoch :14 iterations :2500 loss :3.62396e-05
# epoch :14 iterations :3000 loss :0
# epoch :14 iterations :3500 loss :0
# epoch :14 iterations :4000 loss :9.72748e-05
# epoch :14 iterations :4500 loss :0.0234962
# epoch :14 iterations :5000 loss :0.00048542
# epoch :14 iterations :5500 loss :4.673e-05
# epoch :14 iterations :6000 loss :3.8147e-06
# epoch :14 iterations :6500 loss :9.63211e-05
# epoch :14 iterations :7000 loss :1.04904e-05
# epoch :14 iterations :7500 loss :8.58307e-06
# epoch :14 iterations :8000 loss :0.0309391
# epoch :14 iterations :8500 loss :0.00018692
# epoch :14 iterations :9000 loss :9.53674e-07
# epoch :14 iterations :9500 loss :0
# the average loss after completion of 15 epochs is 0.0217031
# epoch :15 iterations :1 loss :2.86102e-06
# epoch :15 iterations :500 loss :0.00112057
# epoch :15 iterations :1000 loss :9.53674e-07
# epoch :15 iterations :1500 loss :0.00186157
# epoch :15 iterations :2000 loss :0
# epoch :15 iterations :2500 loss :4.673e-05
# epoch :15 iterations :3000 loss :0
# epoch :15 iterations :3500 loss :5.72205e-06
# epoch :15 iterations :4000 loss :0.000162125
# epoch :15 iterations :4500 loss :2.67029e-05
# epoch :15 iterations :5000 loss :0.268433
# epoch :15 iterations :5500 loss :0.000706673
# epoch :15 iterations :6000 loss :9.53674e-07
# epoch :15 iterations :6500 loss :4.95911e-05
# epoch :15 iterations :7000 loss :0.0001297
# epoch :15 iterations :7500 loss :9.53674e-07
# epoch :15 iterations :8000 loss :9.53674e-07
# epoch :15 iterations :8500 loss :3.52859e-05
# epoch :15 iterations :9000 loss :3.33786e-05
# epoch :15 iterations :9500 loss :3.8147e-06
# the average loss after completion of 16 epochs is 0.0256394
# epoch :16 iterations :1 loss :9.53674e-07
# epoch :16 iterations :500 loss :0.000549316
# epoch :16 iterations :1000 loss :0
# epoch :16 iterations :1500 loss :4.00543e-05
# epoch :16 iterations :2000 loss :0
# epoch :16 iterations :2500 loss :7.62939e-06
# epoch :16 iterations :3000 loss :0
# epoch :16 iterations :3500 loss :0
# epoch :16 iterations :4000 loss :0.000654221
# epoch :16 iterations :4500 loss :0.0299988
# epoch :16 iterations :5000 loss :0.000580788
# epoch :16 iterations :5500 loss :0.00107193
# epoch :16 iterations :6000 loss :0
# epoch :16 iterations :6500 loss :4.76837e-06
# epoch :16 iterations :7000 loss :0.000185013
# epoch :16 iterations :7500 loss :0
# epoch :16 iterations :8000 loss :0
# epoch :16 iterations :8500 loss :5.62668e-05
# epoch :16 iterations :9000 loss :2.86102e-06
# epoch :16 iterations :9500 loss :4.00543e-05
# the average loss after completion of 17 epochs is 0.0168727
# epoch :17 iterations :1 loss :0
# epoch :17 iterations :500 loss :6.58035e-05
# epoch :17 iterations :1000 loss :0
# epoch :17 iterations :1500 loss :0.776708
# epoch :17 iterations :2000 loss :0
# epoch :17 iterations :2500 loss :3.8147e-06
# epoch :17 iterations :3000 loss :0
# epoch :17 iterations :3500 loss :0
# epoch :17 iterations :4000 loss :5.81741e-05
# epoch :17 iterations :4500 loss :0.00034523
# epoch :17 iterations :5000 loss :1.23978e-05
# epoch :17 iterations :5500 loss :0.00328827
# epoch :17 iterations :6000 loss :9.53674e-07
# epoch :17 iterations :6500 loss :0.000172615
# epoch :17 iterations :7000 loss :7.05719e-05
# epoch :17 iterations :7500 loss :7.62939e-06
# epoch :17 iterations :8000 loss :8.58307e-06
# epoch :17 iterations :8500 loss :0.00226784
# epoch :17 iterations :9000 loss :8.29697e-05
# epoch :17 iterations :9500 loss :3.62396e-05
# the average loss after completion of 18 epochs is 0.0193899
# epoch :18 iterations :1 loss :9.53674e-07
# epoch :18 iterations :500 loss :8.2016e-05
# epoch :18 iterations :1000 loss :1.90735e-06
# epoch :18 iterations :1500 loss :1.71661e-05
# epoch :18 iterations :2000 loss :0
# epoch :18 iterations :2500 loss :0.000257492
# epoch :18 iterations :3000 loss :0
# epoch :18 iterations :3500 loss :0
# epoch :18 iterations :4000 loss :7.62939e-06
# epoch :18 iterations :4500 loss :7.62939e-05
# epoch :18 iterations :5000 loss :0.000117302
# epoch :18 iterations :5500 loss :0.20551
# epoch :18 iterations :6000 loss :2.09808e-05
# epoch :18 iterations :6500 loss :4.48227e-05
# epoch :18 iterations :7000 loss :5.91278e-05
# epoch :18 iterations :7500 loss :0
# epoch :18 iterations :8000 loss :0.00021553
# epoch :18 iterations :8500 loss :0.000352859
# epoch :18 iterations :9000 loss :7.34329e-05
# epoch :18 iterations :9500 loss :0
# the average loss after completion of 19 epochs is 0.0156473
# epoch :19 iterations :1 loss :0
# epoch :19 iterations :500 loss :9.53674e-07
# epoch :19 iterations :1000 loss :0
# epoch :19 iterations :1500 loss :1.90735e-06
# epoch :19 iterations :2000 loss :0
# epoch :19 iterations :2500 loss :0.01336
# epoch :19 iterations :3000 loss :0
# epoch :19 iterations :3500 loss :0
# epoch :19 iterations :4000 loss :4.86374e-05
# epoch :19 iterations :4500 loss :3.8147e-06
# epoch :19 iterations :5000 loss :0.0153308
# epoch :19 iterations :5500 loss :1.33514e-05
# epoch :19 iterations :6000 loss :1.90735e-06
# epoch :19 iterations :6500 loss :8.58307e-06
# epoch :19 iterations :7000 loss :1.04904e-05
# epoch :19 iterations :7500 loss :2.86102e-06
# epoch :19 iterations :8000 loss :1.62125e-05
# epoch :19 iterations :8500 loss :0.00277472
# epoch :19 iterations :9000 loss :0.000406265
# epoch :19 iterations :9500 loss :0.00017643
# the average loss after completion of 20 epochs is 0.0242543
# CPU times: user 1h 29min 29s, sys: 11min 2s, total: 1h 40min 32s
# Wall time: 1h 40min 35s

# %%
torch.save(model.state_dict(), './data/model_last.pth')

# %%
vocabs.counter.most_common
# Out:
# <bound method Counter.most_common of Counter({'công': 23524, 'thể': 20149, '``': 16345, "''": 16300, 'đầu': 14708, 'hiện': 14454, 'thành': 13516, 'quan': 11930, 'đồng': 11642, 'định': 11507, 'gia': 11308, 'động': 11117, 'hàng': 10863, 'nhân': 10726, 'học': 10290, 'trường': 9687, 'thời': 9331, 'đi': 9301, 'giá': 9184, 'quốc': 8814, 'phát': 8760, 'nam': 8710, 'hai': 8443, 'trung': 8306, 'hợp': 8269, 'vụ': 8180, 'thủ': 8171, 'tình': 8009, 'thực': 7930, 'đối': 7875, 'viên': 7749, 'tiền': 7724, 'dụng': 7718, 'sinh': 7689, 'lý': 7591, 'thông': 7581, '...': 7484, 'hình': 7426, 'hành': 7337, 'hội': 7305, 'giải': 7282, 'trình': 7224, 'cầu': 7080, 'kết': 7061, 'đội': 7024, 'xuất': 6919, 'chủ': 6865, 'việt': 6807, 'tiếp': 6794, 'mỹ': 6644, 'tâm': 6612, 'đường': 6603, 'bệnh': 6590, 'sản': 6569, 'nghiệp': 6470, 'độ': 6391, 'giới': 6335, 'chức': 6302, 'thị': 6292, 'năng': 6163, 'văn': 6095, 'diễn': 6058, 'tế': 6045, 'mặt': 5943, 'máy': 5919, 'nhiên': 5894, 'bình': 5868, 'đại': 5857, 'sĩ': 5808, 'kinh': 5801, 'yêu': 5792, 'đề': 5764, 'dự': 5732, 'dân': 5611, 'ta': 5581, 'tác': 5559, 'liên': 5458, 'sống': 5434, 'báo': 5347, 'an': 5338, 'tài': 5302, 'tư': 5288, 'pháp': 5266, 'doanh': 5221, 'quyết': 5182, 'gian': 5113, 'trận': 5081, 'trọng': 5044, 'thương': 5036, 'cảm': 5017, 'trẻ': 4985, 'bảo': 4983, 'điện': 4968, 'toàn': 4863, 'ty': 4859, 'bóng': 4852, 'đấu': 4816, 'án': 4813, 'trở': 4762, 'sử': 4759, 'triệu': 4753, 'thi': 4641, 'phòng': 4609, 'vị': 4583, 'chất': 4571, 'ban': 4541, 'nội': 4537, 'đạo': 4512, 'bắt': 4499, 'ảnh': 4476, 'hệ': 4465, 'xe': 4434, 'dịch': 4412, 'thống': 4342, 'tổng': 4342, 'phương': 4336, 'lực': 4313, 'cứu': 4277, 'trưởng': 4197, 'nguyễn': 4185, 'tiêu': 4178, 'tập': 4155, 'hà': 4130, 'tổ': 4115, 'đất': 4112, 'thức': 4087, 'tiến': 4049, 'nguyên': 4027, 'giao': 4015, 'triển': 4003, 'đình': 3996, 'nữ': 3979, 'phẩm': 3979, 'thu': 3977, 'trị': 3948, 'tiên': 3945, 'thắng': 3937, 'chứng': 3906, 'vật': 3882, 'phụ': 3871, 'vấn': 3871, 'tra': 3870, 'bàn': 3823, 'chiến': 3803, 'thiết': 3802, 'khu': 3793, 'tham': 3752, 'nghệ': 3748, 'nhạc': 3739, 'bất': 3738, 'hiệu': 3727, 'vệ': 3709, 'ca': 3682, 'minh': 3681, 'tục': 3614, 'bao': 3540, 'giúp': 3526, 'sức': 3514, 'bố': 3502, 'vn': 3474, 'chế': 3455, 'hoàn': 3455, 'nhập': 3448, 'đổi': 3445, 'đánh': 3443, 'cá': 3426, 'hoạt': 3409, 'cảnh': 3398, 'biệt': 3392, 'sát': 3383, 'trang': 3380, 'phim': 3345, 'chuyên': 3340, 'tiếng': 3339, 'sân': 3330, 'sở': 3328, 'hóa': 3313, 'mua': 3304, 'đặc': 3289, 'địa': 3288, 'thay': 3275, 'lập': 3266, 'đơn': 3255, 'kỳ': 3237, 'phạm': 3211, 'nghiên': 3145, 'quyền': 3141, 'tượng': 3121, 'thân': 3107, 'chương': 3078, 'kiến': 3077, 'thuốc': 3055, 'tất': 3047, 'thái': 3041, '10': 3034, 'tỷ': 3030, 'cổ': 3029, 'hôm': 3019, 'khai': 2991, 'giả': 2988, 'cáo': 2985, 'vực': 2976, 'thuật': 2973, 'chi': 2967, 'chồng': 2963, 'trí': 2962, 'liệu': 2944, 'khả': 2928, 'phục': 2909, 'ứng': 2891, 'tử': 2842, 'viện': 2840, 'tỉnh': 2810, 'vợ': 2801, 'kế': 2800, 'giám': 2785, 'usd': 2778, 'châu': 2773, 'vòng': 2772, 'vi': 2765, 'mẹ': 2763, 'khoa': 2760, 'đời': 2760, 'tranh': 2731, 'biến': 2709, 'xã': 2703, 'lợi': 2663, 'luật': 2661, 'chí': 2653, 'quân': 2651, 'mắt': 2650, 'phút': 2624, 'đá': 2601, 'nghị': 2599, 'sách': 2597, 'đông': 2578, 'đàn': 2572, 'chân': 2563, 'dựng': 2558, 'thư': 2556, 'tương': 2553, 'tích': 2542, 'xác': 2533, 'xét': 2531, 'hoa': 2531, 'quản': 2516, 'truyền': 2506, 'xây': 2506, 'vô': 2502, 'phân': 2500, 'tinh': 2487, 'biểu': 2473, 'kiện': 2466, 'trái': 2445, 'phố': 2443, 'nhiệm': 2440, 'gái': 2431, 'khẩu': 2429, 'kiểm': 2423, 'lan': 2421, 'yếu': 2421, 'xử': 2415, 'hạn': 2410, 'tp': 2407, 'ngoại': 2392, 'quy': 2390, 'ký': 2371, 'danh': 2342, 'đốc': 2321, 'cung': 2315, 'mạng': 2314, 'gọi': 2314, 'đẹp': 2306, 'cố': 2298, 'phủ': 2290, 'đoàn': 2284, 'tố': 2281, 'trợ': 2273, 'kỹ': 2246, 'nhật': 2246, 'diện': 2242, 'hồi': 2239, 'đức': 2215, 'nghiệm': 2214, 'hải': 2189, 'tuần': 2171, 'giáo': 2170, 'câu': 2166, 'khí': 2150, 'lịch': 2137, 'âm': 2137, 'nổi': 213 ...
