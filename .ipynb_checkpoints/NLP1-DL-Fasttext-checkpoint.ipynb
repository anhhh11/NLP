# %%
from gensim.models.wrappers import FastText
from gensim.utils import tokenize

# %%
fasttext_model = FastText.load('/mnt/A20CC3B20CC37FB1/cc.vi.300.gs')

# %%
import re
import unicodedata
import torch
import torch.nn as nn
import torch
from torch.autograd import Variable
from torch import optim
from collections import Counter
import torch.nn.functional as F
import pickle
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import nltk
torch.manual_seed(10)
# Enable inline plotting
nltk.download('punkt')
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /home/computer/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# if gpu is to be used
use_cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_cuda else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_cuda else torch.ByteTensor
Tensor = FloatTensor
Variable = torch.autograd.Variable

# %%
file = open('./data/Training_shuf.txt', 'r')
data = []
X = [] # text 
y = [] # label (text)
for line in file:
    row = line.split(' ', 1)
    data.append((row[1].strip(), row[0].split('__')[1]))
    X.append(row[1].strip())
    y.append(row[0].split('__')[1])

# %%
le = preprocessing.LabelEncoder()
le.fit(y)
Y_train = le.transform(y)
number_of_class = le.classes_.size
np.save('./data/classes.npy',le.classes_)

# %%
def from_pretrained(embeddings, freeze=True):
    assert embeddings.dim() == 2, \
         'Embeddings parameter is expected to be 2-dimensional'
    rows, cols = embeddings.shape
    embedding = torch.nn.Embedding(num_embeddings=rows, embedding_dim=cols)
    embedding.weight = torch.nn.Parameter(embeddings)
    embedding.weight.requires_grad = not freeze
    return embedding
class Model(torch.nn.Module) :
    def __init__(self,weights,hidden_dim,number_of_class) :
        super(Model,self).__init__()
        self.hidden_dim = hidden_dim
        embedding_dim = weights.shape[1]
        self.embeddings = from_pretrained(weights)
        self.lstm1 = nn.LSTM(embedding_dim,hidden_dim,dropout=0.2)
        self.linear1 = nn.Linear(hidden_dim,number_of_class)
    def forward(self,inputs,hidden) :
        x = self.embeddings(inputs).view(len(inputs),1,-1)
        lstm_out1,lstm_h1 = self.lstm1(x,hidden)
        x = lstm_out1[-1]
        x = self.linear1(x)
        x = F.log_softmax(x)
        return x,lstm_h1
    def init_hidden(self) :
        return (Variable(torch.zeros(1, 1, self.hidden_dim).type(FloatTensor)),Variable(torch.zeros(1, 1, self.hidden_dim).type(FloatTensor)))
def get_indexes(text):
    return [fasttext_model.wv.vocab.get(t).index for t in tokenize(text) if t in fasttext_model.wv.vocab]
def save_params(model, i):
    pl = list(model.parameters())
    pl = [p for i,p in enumerate(pl) if i > 0]
    torch.save(pl,'./data/params-%d.dat' % i)
def load_params(model, params_path):
    pl = list(model.parameters())
    pl = [p for i,p in enumerate(pl) if i > 0]
    pll = torch.load(params_path)
    for p1, p2 in zip(pl, pll):
        p1.data = p2.data

# %%
weights = FloatTensor(fasttext_model.wv.syn0)

# %%
model = Model(weights,80,number_of_class)

# %%
if(use_cuda):
    model.cuda()

# %%
loss_function = nn.NLLLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3)

# %%
# %%time
epochs = 30

print('starting training')
X_sample = X#[2000:4000]
Y_train_sample = Y_train#[2000:4000]
for i in range(epochs):
    avg_loss = 0.0
    for idx, (x, y_train) in enumerate(zip(X_sample, Y_train_sample)):
        if not idx == 0:
            input_data = get_indexes(x)
            input_data = Variable(LongTensor(input_data))
            y_train = y_train.item()
            target_data = Variable(LongTensor([y_train]))
            hidden = model.init_hidden()
            model.zero_grad()
            y_pred,_ = model(input_data,hidden)
            loss = loss_function(y_pred,target_data)
            avg_loss += loss.data[0]
            
            if idx%500 == 0 or idx == 1:
                print('epoch :%d iterations :%d loss :%g'%(i,idx,loss.data[0]))
            loss.backward()
            optimizer.step()
    save_params(model, i)
    print('the average loss after completion of %d epochs is %g'%((i+1),(avg_loss/len(X_sample))))
# Out:
# starting training
# /home/computer/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# epoch :0 iterations :1 loss :2.19914
# epoch :0 iterations :500 loss :1.82093
# epoch :0 iterations :1000 loss :2.09222
# epoch :0 iterations :1500 loss :1.01968
# epoch :0 iterations :2000 loss :1.8425
# epoch :0 iterations :2500 loss :2.09945
# epoch :0 iterations :3000 loss :2.22924
# epoch :0 iterations :3500 loss :1.68119
# epoch :0 iterations :4000 loss :1.85766
# epoch :0 iterations :4500 loss :1.75222
# epoch :0 iterations :5000 loss :1.7385
# epoch :0 iterations :5500 loss :2.02257
# epoch :0 iterations :6000 loss :2.5215
# epoch :0 iterations :6500 loss :1.48666
# epoch :0 iterations :7000 loss :0.507241
# epoch :0 iterations :7500 loss :2.02556
# epoch :0 iterations :8000 loss :0.96921
# epoch :0 iterations :8500 loss :3.38435
# epoch :0 iterations :9000 loss :0.642102
# epoch :0 iterations :9500 loss :1.51792
# the average loss after completion of 1 epochs is 1.90912
# epoch :1 iterations :1 loss :1.71657
# epoch :1 iterations :500 loss :2.87758
# epoch :1 iterations :1000 loss :1.13411
# epoch :1 iterations :1500 loss :0.337128
# epoch :1 iterations :2000 loss :1.64539
# epoch :1 iterations :2500 loss :2.64861
# epoch :1 iterations :3000 loss :0.607482
# epoch :1 iterations :3500 loss :2.05443
# epoch :1 iterations :4000 loss :2.02042
# epoch :1 iterations :4500 loss :0.0745997
# epoch :1 iterations :5000 loss :1.3535
# epoch :1 iterations :5500 loss :2.75345
# epoch :1 iterations :6000 loss :1.93628
# epoch :1 iterations :6500 loss :1.43583
# epoch :1 iterations :7000 loss :1.57072
# epoch :1 iterations :7500 loss :0.920937
# epoch :1 iterations :8000 loss :1.46492
# epoch :1 iterations :8500 loss :1.73148
# epoch :1 iterations :9000 loss :0.135778
# epoch :1 iterations :9500 loss :1.40713
# the average loss after completion of 2 epochs is 1.48839
# epoch :2 iterations :1 loss :0.132607
# epoch :2 iterations :500 loss :0.0490274
# epoch :2 iterations :1000 loss :1.6534
# epoch :2 iterations :1500 loss :0.0733824
# epoch :2 iterations :2000 loss :0.0999999
# epoch :2 iterations :2500 loss :1.33557
# epoch :2 iterations :3000 loss :1.23637
# epoch :2 iterations :3500 loss :0.309097
# epoch :2 iterations :4000 loss :0.214275
# epoch :2 iterations :4500 loss :1.06349
# epoch :2 iterations :5000 loss :0.652111
# epoch :2 iterations :5500 loss :1.31041
# epoch :2 iterations :6000 loss :0.0814118
# epoch :2 iterations :6500 loss :1.41552
# epoch :2 iterations :7000 loss :0.0439639
# epoch :2 iterations :7500 loss :0.377664
# epoch :2 iterations :8000 loss :0.599758
# epoch :2 iterations :8500 loss :1.76252
# epoch :2 iterations :9000 loss :0.0789137
# epoch :2 iterations :9500 loss :0.950853
# the average loss after completion of 3 epochs is 1.14908
# epoch :3 iterations :1 loss :0.133156
# epoch :3 iterations :500 loss :2.43928
# epoch :3 iterations :1000 loss :0.490782
# epoch :3 iterations :1500 loss :0.657507
# epoch :3 iterations :2000 loss :0.0159178
# epoch :3 iterations :2500 loss :0.175842
# epoch :3 iterations :3000 loss :0.00566006
# epoch :3 iterations :3500 loss :0.0164914
# epoch :3 iterations :4000 loss :0.106497
# epoch :3 iterations :4500 loss :0.0375376
# epoch :3 iterations :5000 loss :0.571383
# epoch :3 iterations :5500 loss :0.70006
# epoch :3 iterations :6000 loss :0.145155
# epoch :3 iterations :6500 loss :0.401869
# epoch :3 iterations :7000 loss :0.0475931
# epoch :3 iterations :7500 loss :0.35092
# epoch :3 iterations :8000 loss :0.0542326
# epoch :3 iterations :8500 loss :0.644022
# epoch :3 iterations :9000 loss :0.0877819
# epoch :3 iterations :9500 loss :0.748488
# the average loss after completion of 4 epochs is 0.951446
# epoch :4 iterations :1 loss :0.356154
# epoch :4 iterations :500 loss :1.01617
# epoch :4 iterations :1000 loss :0.0349622
# epoch :4 iterations :1500 loss :1.85149
# epoch :4 iterations :2000 loss :0.0756032
# epoch :4 iterations :2500 loss :0.331564
# epoch :4 iterations :3000 loss :0.00465584
# epoch :4 iterations :3500 loss :0.159421
# epoch :4 iterations :4000 loss :0.352193
# epoch :4 iterations :4500 loss :0.476352
# epoch :4 iterations :5000 loss :0.437429
# epoch :4 iterations :5500 loss :0.800082
# epoch :4 iterations :6000 loss :0.0878828
# epoch :4 iterations :6500 loss :0.207595
# epoch :4 iterations :7000 loss :0.0602059
# epoch :4 iterations :7500 loss :0.0821157
# epoch :4 iterations :8000 loss :0.208391
# epoch :4 iterations :8500 loss :2.42895
# epoch :4 iterations :9000 loss :0.0819969
# epoch :4 iterations :9500 loss :1.57967
# the average loss after completion of 5 epochs is 0.795593
# epoch :5 iterations :1 loss :0.0299959
# epoch :5 iterations :500 loss :0.0191722
# epoch :5 iterations :1000 loss :0.00781584
# epoch :5 iterations :1500 loss :0.375103
# epoch :5 iterations :2000 loss :0.0364704
# epoch :5 iterations :2500 loss :0.185997
# epoch :5 iterations :3000 loss :0.00247526
# epoch :5 iterations :3500 loss :0.0254126
# epoch :5 iterations :4000 loss :0.0415149
# epoch :5 iterations :4500 loss :0.0231094
# epoch :5 iterations :5000 loss :0.562749
# epoch :5 iterations :5500 loss :0.199072
# epoch :5 iterations :6000 loss :0.0155616
# epoch :5 iterations :6500 loss :0.0213385
# epoch :5 iterations :7000 loss :0.0459547
# epoch :5 iterations :7500 loss :0.0353227
# epoch :5 iterations :8000 loss :0.066855
# epoch :5 iterations :8500 loss :1.53141
# epoch :5 iterations :9000 loss :0.0206347
# epoch :5 iterations :9500 loss :0.105087
# the average loss after completion of 6 epochs is 0.589032
# epoch :6 iterations :1 loss :0.0264454
# epoch :6 iterations :500 loss :0.0180268
# epoch :6 iterations :1000 loss :0.00843382
# epoch :6 iterations :1500 loss :0.0386982
# epoch :6 iterations :2000 loss :0.0189252
# epoch :6 iterations :2500 loss :0.0817451
# epoch :6 iterations :3000 loss :0.00134754
# epoch :6 iterations :3500 loss :0.00602818
# epoch :6 iterations :4000 loss :0.0295906
# epoch :6 iterations :4500 loss :0.0426836
# epoch :6 iterations :5000 loss :0.244124
# epoch :6 iterations :5500 loss :0.115393
# epoch :6 iterations :6000 loss :0.00155163
# epoch :6 iterations :6500 loss :0.00826693
# epoch :6 iterations :7000 loss :0.0210643
# epoch :6 iterations :7500 loss :0.0525017
# epoch :6 iterations :8000 loss :0.0883274
# epoch :6 iterations :8500 loss :0.71347
# epoch :6 iterations :9000 loss :0.0126042
# epoch :6 iterations :9500 loss :0.0197334
# the average loss after completion of 7 epochs is 0.44257
# epoch :7 iterations :1 loss :0.0120168
# epoch :7 iterations :500 loss :0.394245
# epoch :7 iterations :1000 loss :0.00163078
# epoch :7 iterations :1500 loss :0.0106153
# epoch :7 iterations :2000 loss :0.00178432
# epoch :7 iterations :2500 loss :0.00444889
# epoch :7 iterations :3000 loss :0.000150681
# epoch :7 iterations :3500 loss :0.000554085
# epoch :7 iterations :4000 loss :0.0367274
# epoch :7 iterations :4500 loss :0.0304899
# epoch :7 iterations :5000 loss :0.0413742
# epoch :7 iterations :5500 loss :0.0381384
# epoch :7 iterations :6000 loss :0.000171661
# epoch :7 iterations :6500 loss :0.00352383
# epoch :7 iterations :7000 loss :0.00601435
# epoch :7 iterations :7500 loss :0.0411115
# epoch :7 iterations :8000 loss :0.0712075
# epoch :7 iterations :8500 loss :0.241866
# epoch :7 iterations :9000 loss :0.00825071
# epoch :7 iterations :9500 loss :0.0296235
# the average loss after completion of 8 epochs is 0.34684
# epoch :8 iterations :1 loss :0.0118418
# epoch :8 iterations :500 loss :0.0143051
# epoch :8 iterations :1000 loss :0.00243998
# epoch :8 iterations :1500 loss :0.00523806
# epoch :8 iterations :2000 loss :0.00223398
# epoch :8 iterations :2500 loss :0.0218854
# epoch :8 iterations :3000 loss :0.000266075
# epoch :8 iterations :3500 loss :0.000258446
# epoch :8 iterations :4000 loss :0.0302119
# epoch :8 iterations :4500 loss :0.0258541
# epoch :8 iterations :5000 loss :0.107133
# epoch :8 iterations :5500 loss :0.0243163
# epoch :8 iterations :6000 loss :3.71933e-05
# epoch :8 iterations :6500 loss :0.0123625
# epoch :8 iterations :7000 loss :0.00666428
# epoch :8 iterations :7500 loss :0.026618
# epoch :8 iterations :8000 loss :0.0178037
# epoch :8 iterations :8500 loss :0.0631227
# epoch :8 iterations :9000 loss :0.00678873
# epoch :8 iterations :9500 loss :0.113191
# the average loss after completion of 9 epochs is 0.27067
# epoch :9 iterations :1 loss :0.00248909
# epoch :9 iterations :500 loss :0.00865936
# epoch :9 iterations :1000 loss :0.000534058
# epoch :9 iterations :1500 loss :0.00438404
# epoch :9 iterations :2000 loss :0.000193596
# epoch :9 iterations :2500 loss :0.00457478
# epoch :9 iterations :3000 loss :3.62396e-05
# epoch :9 iterations :3500 loss :6.38962e-05
# epoch :9 iterations :4000 loss :0.0509868
# epoch :9 iterations :4500 loss :0.0184765
# epoch :9 iterations :5000 loss :0.117779
# epoch :9 iterations :5500 loss :0.0212955
# epoch :9 iterations :6000 loss :0.000110626
# epoch :9 iterations :6500 loss :0.000488281
# epoch :9 iterations :7000 loss :0.0141387
# epoch :9 iterations :7500 loss :0.0054059
# epoch :9 iterations :8000 loss :0.00305653
# epoch :9 iterations :8500 loss :0.153145
# epoch :9 iterations :9000 loss :0.00282669
# epoch :9 iterations :9500 loss :0.0382972
# the average loss after completion of 10 epochs is 0.201455
# epoch :10 iterations :1 loss :0.000548363
# epoch :10 iterations :500 loss :0.011425
# epoch :10 iterations :1000 loss :0.000112534
# epoch :10 iterations :1500 loss :0.000841141
# epoch :10 iterations :2000 loss :0.000193596
# epoch :10 iterations :2500 loss :0.00616074
# epoch :10 iterations :3000 loss :7.15256e-05
# epoch :10 iterations :3500 loss :6.67572e-05
# epoch :10 iterations :4000 loss :0.0251665
# epoch :10 iterations :4500 loss :0.0073328
# epoch :10 iterations :5000 loss :0.00712681
# epoch :10 iterations :5500 loss :0.0349822
# epoch :10 iterations :6000 loss :5.72205e-06
# epoch :10 iterations :6500 loss :0.000341415
# epoch :10 iterations :7000 loss :0.00431108
# epoch :10 iterations :7500 loss :0.00214386
# epoch :10 iterations :8000 loss :0.00160503
# epoch :10 iterations :8500 loss :0.00447655
# epoch :10 iterations :9000 loss :0.0081892
# epoch :10 iterations :9500 loss :0.028605
# the average loss after completion of 11 epochs is 0.149224
# epoch :11 iterations :1 loss :0.000177383
# epoch :11 iterations :500 loss :0.0242224
# epoch :11 iterations :1000 loss :0.0013361
# epoch :11 iterations :1500 loss :0.0013113
# epoch :11 iterations :2000 loss :8.39233e-05
# epoch :11 iterations :2500 loss :0.0061841
# epoch :11 iterations :3000 loss :4.95911e-05
# epoch :11 iterations :3500 loss :7.05719e-05
# epoch :11 iterations :4000 loss :0.145401
# epoch :11 iterations :4500 loss :0.00310802
# epoch :11 iterations :5000 loss :0.00118828
# epoch :11 iterations :5500 loss :0.031878
# epoch :11 iterations :6000 loss :7.62939e-06
# epoch :11 iterations :6500 loss :9.91821e-05
# epoch :11 iterations :7000 loss :0.00239372
# epoch :11 iterations :7500 loss :0.000892162
# epoch :11 iterations :8000 loss :0.00349474
# epoch :11 iterations :8500 loss :0.0034852
# epoch :11 iterations :9000 loss :0.00158215
# epoch :11 iterations :9500 loss :0.0127068
# the average loss after completion of 12 epochs is 0.108026
# epoch :12 iterations :1 loss :0.000125885
# epoch :12 iterations :500 loss :0.0126653
# epoch :12 iterations :1000 loss :0.000136375
# epoch :12 iterations :1500 loss :0.00145912
# epoch :12 iterations :2000 loss :2.95639e-05
# epoch :12 iterations :2500 loss :0.00199604
# epoch :12 iterations :3000 loss :1.90735e-06
# epoch :12 iterations :3500 loss :1.23978e-05
# epoch :12 iterations :4000 loss :0.00881004
# epoch :12 iterations :4500 loss :0.000355721
# epoch :12 iterations :5000 loss :0.000172615
# epoch :12 iterations :5500 loss :0.0331364
# epoch :12 iterations :6000 loss :1.90735e-06
# epoch :12 iterations :6500 loss :2.86102e-05
# epoch :12 iterations :7000 loss :0.000733376
# epoch :12 iterations :7500 loss :0.00172997
# epoch :12 iterations :8000 loss :0.00079155
# epoch :12 iterations :8500 loss :0.00230026
# epoch :12 iterations :9000 loss :0.00283051
# epoch :12 iterations :9500 loss :0.00281525
# the average loss after completion of 13 epochs is 0.0847273
# epoch :13 iterations :1 loss :0.000252724
# epoch :13 iterations :500 loss :0.0660572
# epoch :13 iterations :1000 loss :8.86917e-05
# epoch :13 iterations :1500 loss :0.000523567
# epoch :13 iterations :2000 loss :8.01086e-05
# epoch :13 iterations :2500 loss :0.00329351
# epoch :13 iterations :3000 loss :4.76837e-06
# epoch :13 iterations :3500 loss :3.62396e-05
# epoch :13 iterations :4000 loss :0.0682063
# epoch :13 iterations :4500 loss :0.000403404
# epoch :13 iterations :5000 loss :0.00256729
# epoch :13 iterations :5500 loss :0.000930786
# epoch :13 iterations :6000 loss :9.53674e-07
# epoch :13 iterations :6500 loss :2.47955e-05
# epoch :13 iterations :7000 loss :0.000826836
# epoch :13 iterations :7500 loss :0.000226021
# epoch :13 iterations :8000 loss :0.000509262
# epoch :13 iterations :8500 loss :0.0120502
# epoch :13 iterations :9000 loss :0.000124931
# epoch :13 iterations :9500 loss :0.0107222
# the average loss after completion of 14 epochs is 0.0662125
# epoch :14 iterations :1 loss :0.000264168
# epoch :14 iterations :500 loss :0.00121212
# epoch :14 iterations :1000 loss :9.53674e-06
# epoch :14 iterations :1500 loss :0.00477409
# epoch :14 iterations :2000 loss :2.09808e-05
# epoch :14 iterations :2500 loss :0.0127416
# epoch :14 iterations :3000 loss :4.76837e-06
# epoch :14 iterations :3500 loss :1.23978e-05
# epoch :14 iterations :4000 loss :0.00295973
# epoch :14 iterations :4500 loss :0.000250816
# epoch :14 iterations :5000 loss :3.62396e-05
# epoch :14 iterations :5500 loss :0.171683
# epoch :14 iterations :6000 loss :0
# epoch :14 iterations :6500 loss :9.53674e-06
# epoch :14 iterations :7000 loss :2.00272e-05
# epoch :14 iterations :7500 loss :0.000543594
# epoch :14 iterations :8000 loss :9.25064e-05
# epoch :14 iterations :8500 loss :0.0155978
# epoch :14 iterations :9000 loss :0.000132561
# epoch :14 iterations :9500 loss :0.058979
# the average loss after completion of 15 epochs is 0.0512474
# epoch :15 iterations :1 loss :9.44138e-05
# epoch :15 iterations :500 loss :0.00378036
# epoch :15 iterations :1000 loss :0.000247002
# epoch :15 iterations :1500 loss :0.00026226
# epoch :15 iterations :2000 loss :1.90735e-05
# epoch :15 iterations :2500 loss :0.00146914
# epoch :15 iterations :3000 loss :1.90735e-06
# epoch :15 iterations :3500 loss :3.8147e-06
# epoch :15 iterations :4000 loss :0.000171661
# epoch :15 iterations :4500 loss :1.90735e-05
# epoch :15 iterations :5000 loss :0.00120163
# epoch :15 iterations :5500 loss :0.00127029
# epoch :15 iterations :6000 loss :9.53674e-07
# epoch :15 iterations :6500 loss :1.90735e-06
# epoch :15 iterations :7000 loss :5.53131e-05
# epoch :15 iterations :7500 loss :0.000238419
# epoch :15 iterations :8000 loss :0.000155449
# epoch :15 iterations :8500 loss :0.014123
# epoch :15 iterations :9000 loss :0.000107765
# epoch :15 iterations :9500 loss :0.00352383
# the average loss after completion of 16 epochs is 0.0454862
# epoch :16 iterations :1 loss :0.000642776
# epoch :16 iterations :500 loss :0.00248623
# epoch :16 iterations :1000 loss :1.43051e-05
# epoch :16 iterations :1500 loss :1.14441e-05
# epoch :16 iterations :2000 loss :1.81198e-05
# epoch :16 iterations :2500 loss :0.00128698
# epoch :16 iterations :3000 loss :9.53674e-07
# epoch :16 iterations :3500 loss :1.23978e-05
# epoch :16 iterations :4000 loss :6.86646e-05
# epoch :16 iterations :4500 loss :9.53674e-07
# epoch :16 iterations :5000 loss :0.00038147
# epoch :16 iterations :5500 loss :0.0120287
# epoch :16 iterations :6000 loss :0
# epoch :16 iterations :6500 loss :1.14441e-05
# epoch :16 iterations :7000 loss :3.91006e-05
# epoch :16 iterations :7500 loss :0.000265121
# epoch :16 iterations :8000 loss :0.000131607
# epoch :16 iterations :8500 loss :0.000775337
# epoch :16 iterations :9000 loss :0.00769138
# epoch :16 iterations :9500 loss :0.00353241
# the average loss after completion of 17 epochs is 0.040054
# epoch :17 iterations :1 loss :4.48227e-05
# epoch :17 iterations :500 loss :0.00273991
# epoch :17 iterations :1000 loss :7.62939e-06
# epoch :17 iterations :1500 loss :0.0269198
# epoch :17 iterations :2000 loss :2.86102e-06
# epoch :17 iterations :2500 loss :0.001297
# epoch :17 iterations :3000 loss :2.86102e-06
# epoch :17 iterations :3500 loss :0
# epoch :17 iterations :4000 loss :0.00185394
# epoch :17 iterations :4500 loss :2.38419e-05
# epoch :17 iterations :5000 loss :0.00266218
# epoch :17 iterations :5500 loss :0.674574
# epoch :17 iterations :6000 loss :0
# epoch :17 iterations :6500 loss :2.67029e-05
# epoch :17 iterations :7000 loss :1.62125e-05
# epoch :17 iterations :7500 loss :0.00030899
# epoch :17 iterations :8000 loss :5.72205e-05
# epoch :17 iterations :8500 loss :0.000971317
# epoch :17 iterations :9000 loss :5.72205e-06
# epoch :17 iterations :9500 loss :0.0108852
# the average loss after completion of 18 epochs is 0.0358108
# epoch :18 iterations :1 loss :3.33786e-05
# epoch :18 iterations :500 loss :0.00432825
# epoch :18 iterations :1000 loss :4.76837e-06
# epoch :18 iterations :1500 loss :5.72205e-06
# epoch :18 iterations :2000 loss :9.53674e-07
# epoch :18 iterations :2500 loss :0.00257492
# epoch :18 iterations :3000 loss :8.58307e-06
# epoch :18 iterations :3500 loss :8.58307e-06
# epoch :18 iterations :4000 loss :0.00216866
# epoch :18 iterations :4500 loss :2.86102e-06
# epoch :18 iterations :5000 loss :0.00100422
# epoch :18 iterations :5500 loss :0.000691414
# epoch :18 iterations :6000 loss :0
# epoch :18 iterations :6500 loss :9.53674e-07
# epoch :18 iterations :7000 loss :5.72205e-06
# epoch :18 iterations :7500 loss :1.43051e-05
# epoch :18 iterations :8000 loss :1.23978e-05
# epoch :18 iterations :8500 loss :0.00051403
# epoch :18 iterations :9000 loss :0.00275707
# epoch :18 iterations :9500 loss :0.00235271
# the average loss after completion of 19 epochs is 0.0338723
# epoch :19 iterations :1 loss :3.8147e-05
# epoch :19 iterations :500 loss :0.00142193
# epoch :19 iterations :1000 loss :0
# epoch :19 iterations :1500 loss :1.52588e-05
# epoch :19 iterations :2000 loss :1.90735e-06
# epoch :19 iterations :2500 loss :2.76566e-05
# epoch :19 iterations :3000 loss :1.90735e-06
# epoch :19 iterations :3500 loss :9.53674e-07
# epoch :19 iterations :4000 loss :0.000847816
# epoch :19 iterations :4500 loss :6.67572e-06
# epoch :19 iterations :5000 loss :8.39233e-05
# epoch :19 iterations :5500 loss :0.000697136
# epoch :19 iterations :6000 loss :0
# epoch :19 iterations :6500 loss :0
# epoch :19 iterations :7000 loss :2.38419e-05
# epoch :19 iterations :7500 loss :3.24249e-05
# epoch :19 iterations :8000 loss :0.000125885
# epoch :19 iterations :8500 loss :7.15256e-05
# epoch :19 iterations :9000 loss :0.000361443
# epoch :19 iterations :9500 loss :0.0874681
# the average loss after completion of 20 epochs is 0.0255405
# epoch :20 iterations :1 loss :1.90735e-05
# epoch :20 iterations :500 loss :0.000506401
# epoch :20 iterations :1000 loss :0
# epoch :20 iterations :1500 loss :3.05176e-05
# epoch :20 iterations :2000 loss :0
# epoch :20 iterations :2500 loss :0.000109673
# epoch :20 iterations :3000 loss :9.53674e-07
# epoch :20 iterations :3500 loss :9.53674e-07
# epoch :20 iterations :4000 loss :0.000299454
# epoch :20 iterations :4500 loss :6.67572e-06
# epoch :20 iterations :5000 loss :0.000738144
# epoch :20 iterations :5500 loss :0.00305939
# epoch :20 iterations :6000 loss :0
# epoch :20 iterations :6500 loss :0
# epoch :20 iterations :7000 loss :0.000315666
# epoch :20 iterations :7500 loss :1.52588e-05
# epoch :20 iterations :8000 loss :4.19617e-05
# epoch :20 iterations :8500 loss :1.90735e-05
# epoch :20 iterations :9000 loss :0.000326157
# epoch :20 iterations :9500 loss :0.000124931
# the average loss after completion of 21 epochs is 0.0217591
# epoch :21 iterations :1 loss :2.09808e-05
# epoch :21 iterations :500 loss :0.000468254
# epoch :21 iterations :1000 loss :0
# epoch :21 iterations :1500 loss :4.1008e-05
# epoch :21 iterations :2000 loss :9.53674e-07
# epoch :21 iterations :2500 loss :0.00109816
# epoch :21 iterations :3000 loss :9.53674e-07
# epoch :21 iterations :3500 loss :0
# epoch :21 iterations :4000 loss :0.000629902
# epoch :21 iterations :4500 loss :4.76837e-06
# epoch :21 iterations :5000 loss :2.28882e-05
# epoch :21 iterations :5500 loss :0.00471687
# epoch :21 iterations :6000 loss :0
# epoch :21 iterations :6500 loss :0
# epoch :21 iterations :7000 loss :3.8147e-06
# epoch :21 iterations :7500 loss :6.67572e-06
# epoch :21 iterations :8000 loss :1.33514e-05
# epoch :21 iterations :8500 loss :1.04904e-05
# epoch :21 iterations :9000 loss :0.00291157
# epoch :21 iterations :9500 loss :5.34058e-05
# the average loss after completion of 22 epochs is 0.0230475
# epoch :22 iterations :1 loss :5.14984e-05
# epoch :22 iterations :500 loss :0.000107765
# epoch :22 iterations :1000 loss :0
# epoch :22 iterations :1500 loss :7.62939e-06
# epoch :22 iterations :2000 loss :0
# epoch :22 iterations :2500 loss :9.53674e-07
# epoch :22 iterations :3000 loss :0
# epoch :22 iterations :3500 loss :0
# epoch :22 iterations :4000 loss :0.00114584
# epoch :22 iterations :4500 loss :9.53674e-07
# epoch :22 iterations :5000 loss :0.00025177
# epoch :22 iterations :5500 loss :0.0323782
# epoch :22 iterations :6000 loss :0
# epoch :22 iterations :6500 loss :0
# epoch :22 iterations :7000 loss :9.53674e-07
# epoch :22 iterations :7500 loss :2.38419e-05
# epoch :22 iterations :8000 loss :0.000362396
# epoch :22 iterations :8500 loss :9.53674e-07
# epoch :22 iterations :9000 loss :0.00124454
# epoch :22 iterations :9500 loss :0.000208855
# the average loss after completion of 23 epochs is 0.0217637
# epoch :23 iterations :1 loss :0.000136375
# epoch :23 iterations :500 loss :0.00679684
# epoch :23 iterations :1000 loss :0
# epoch :23 iterations :1500 loss :5.72205e-06
# epoch :23 iterations :2000 loss :0
# epoch :23 iterations :2500 loss :0.000109673
# epoch :23 iterations :3000 loss :0
# epoch :23 iterations :3500 loss :0
# epoch :23 iterations :4000 loss :0.000561714
# epoch :23 iterations :4500 loss :0.000781059
# epoch :23 iterations :5000 loss :7.43866e-05
# epoch :23 iterations :5500 loss :0.00923061
# epoch :23 iterations :6000 loss :0
# epoch :23 iterations :6500 loss :0
# epoch :23 iterations :7000 loss :1.71661e-05
# epoch :23 iterations :7500 loss :0
# epoch :23 iterations :8000 loss :9.44138e-05
# epoch :23 iterations :8500 loss :0
# epoch :23 iterations :9000 loss :0.00155544
# epoch :23 iterations :9500 loss :2.67029e-05
# the average loss after completion of 24 epochs is 0.0212123
# epoch :24 iterations :1 loss :9.53674e-07
# epoch :24 iterations :500 loss :0.00034523
# epoch :24 iterations :1000 loss :0
# epoch :24 iterations :1500 loss :0
# epoch :24 iterations :2000 loss :2.86102e-06
# epoch :24 iterations :2500 loss :3.8147e-06
# epoch :24 iterations :3000 loss :0
# epoch :24 iterations :3500 loss :0
# epoch :24 iterations :4000 loss :0.000659943
# epoch :24 iterations :4500 loss :6.67572e-06
# epoch :24 iterations :5000 loss :0.419196
# epoch :24 iterations :5500 loss :0.039547
# epoch :24 iterations :6000 loss :0
# epoch :24 iterations :6500 loss :0
# epoch :24 iterations :7000 loss :1.04904e-05
# epoch :24 iterations :7500 loss :0
# epoch :24 iterations :8000 loss :2.67029e-05
# epoch :24 iterations :8500 loss :6.67572e-06
# epoch :24 iterations :9000 loss :0.000576019
# epoch :24 iterations :9500 loss :0.000582695
# the average loss after completion of 25 epochs is 0.0143307
# epoch :25 iterations :1 loss :0
# epoch :25 iterations :500 loss :0.000146866
# epoch :25 iterations :1000 loss :0
# epoch :25 iterations :1500 loss :3.8147e-06
# epoch :25 iterations :2000 loss :9.53674e-07
# epoch :25 iterations :2500 loss :1.14441e-05
# epoch :25 iterations :3000 loss :0
# epoch :25 iterations :3500 loss :0
# epoch :25 iterations :4000 loss :0.0004673
# epoch :25 iterations :4500 loss :1.90735e-06
# epoch :25 iterations :5000 loss :0
# epoch :25 iterations :5500 loss :0.0313454
# epoch :25 iterations :6000 loss :0
# epoch :25 iterations :6500 loss :0
# epoch :25 iterations :7000 loss :3.8147e-06
# epoch :25 iterations :7500 loss :0
# epoch :25 iterations :8000 loss :8.58307e-06
# epoch :25 iterations :8500 loss :2.86102e-06
# epoch :25 iterations :9000 loss :1.43051e-05
# epoch :25 iterations :9500 loss :0.00222301
# the average loss after completion of 26 epochs is 0.0159416
# epoch :26 iterations :1 loss :0
# epoch :26 iterations :500 loss :0.000634193
# epoch :26 iterations :1000 loss :0
# epoch :26 iterations :1500 loss :9.53674e-07
# epoch :26 iterations :2000 loss :3.8147e-06
# epoch :26 iterations :2500 loss :1.90735e-06
# epoch :26 iterations :3000 loss :2.86102e-06
# epoch :26 iterations :3500 loss :0
# epoch :26 iterations :4000 loss :0.00829649
# epoch :26 iterations :4500 loss :0.000102043
# epoch :26 iterations :5000 loss :0
# epoch :26 iterations :5500 loss :0.00222874
# epoch :26 iterations :6000 loss :0
# epoch :26 iterations :6500 loss :0
# epoch :26 iterations :7000 loss :8.58307e-06
# epoch :26 iterations :7500 loss :0
# epoch :26 iterations :8000 loss :8.67844e-05
# epoch :26 iterations :8500 loss :4.76837e-06
# epoch :26 iterations :9000 loss :0.000115395
# epoch :26 iterations :9500 loss :0.00241184
# the average loss after completion of 27 epochs is 0.0154651
# epoch :27 iterations :1 loss :0
# epoch :27 iterations :500 loss :0.000245094
# epoch :27 iterations :1000 loss :0
# epoch :27 iterations :1500 loss :2.86102e-06
# epoch :27 iterations :2000 loss :2.09808e-05
# epoch :27 iterations :2500 loss :1.90735e-06
# epoch :27 iterations :3000 loss :0
# epoch :27 iterations :3500 loss :0
# epoch :27 iterations :4000 loss :0.000255108
# epoch :27 iterations :4500 loss :2.67029e-05
# epoch :27 iterations :5000 loss :0
# epoch :27 iterations :5500 loss :0.0481024
# epoch :27 iterations :6000 loss :0
# epoch :27 iterations :6500 loss :9.53674e-07
# epoch :27 iterations :7000 loss :1.23978e-05
# epoch :27 iterations :7500 loss :9.53674e-07
# epoch :27 iterations :8000 loss :7.62939e-05
# epoch :27 iterations :8500 loss :0
# epoch :27 iterations :9000 loss :0.0013032
# epoch :27 iterations :9500 loss :0.150668
# the average loss after completion of 28 epochs is 0.0196444
# epoch :28 iterations :1 loss :1.90735e-06
# epoch :28 iterations :500 loss :0.00227356
# epoch :28 iterations :1000 loss :0
# epoch :28 iterations :1500 loss :9.53674e-07
# epoch :28 iterations :2000 loss :5.53131e-05
# epoch :28 iterations :2500 loss :0
# epoch :28 iterations :3000 loss :0
# epoch :28 iterations :3500 loss :0
# epoch :28 iterations :4000 loss :0.00111198
# epoch :28 iterations :4500 loss :9.05991e-05
# epoch :28 iterations :5000 loss :0.000543594
# epoch :28 iterations :5500 loss :0.000916481
# epoch :28 iterations :6000 loss :0
# epoch :28 iterations :6500 loss :0
# epoch :28 iterations :7000 loss :1.14441e-05
# epoch :28 iterations :7500 loss :0
# epoch :28 iterations :8000 loss :0.000610352
# epoch :28 iterations :8500 loss :6.67572e-06
# epoch :28 iterations :9000 loss :0.000979424
# epoch :28 iterations :9500 loss :1.33514e-05
# the average loss after completion of 29 epochs is 0.0151943
# epoch :29 iterations :1 loss :9.53674e-07
# epoch :29 iterations :500 loss :0.000361443
# epoch :29 iterations :1000 loss :0
# epoch :29 iterations :1500 loss :4.76837e-06
# epoch :29 iterations :2000 loss :1.04904e-05
# epoch :29 iterations :2500 loss :0
# epoch :29 iterations :3000 loss :0
# epoch :29 iterations :3500 loss :0
# epoch :29 iterations :4000 loss :0.00012207
# epoch :29 iterations :4500 loss :1.90735e-06
# epoch :29 iterations :5000 loss :0
# epoch :29 iterations :5500 loss :8.10623e-05
# epoch :29 iterations :6000 loss :0
# epoch :29 iterations :6500 loss :0
# epoch :29 iterations :7000 loss :9.53674e-07
# epoch :29 iterations :7500 loss :9.53674e-07
# epoch :29 iterations :8000 loss :1.04904e-05
# epoch :29 iterations :8500 loss :0
# epoch :29 iterations :9000 loss :0.000430107
# epoch :29 iterations :9500 loss :8.58307e-06
# the average loss after completion of 30 epochs is 0.0124221
# CPU times: user 2h 5min 15s, sys: 27min 1s, total: 2h 32min 16s
# Wall time: 2h 32min 24s

# %%
save_params(model, -1)

# %%
# torch.save(model.state_dict(), './data/model_last.pth')
# torch.save(model, './data/model_last.pth')

# %%
# load_params(model, './data/params.dat')
